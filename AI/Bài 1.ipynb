# %%
import folium

# %%
m = folium.Map(location=[10.761167, 106.668338], zoom_start=15)
folium.Marker([10.761167, 106.668338], popup="Đại học Kinh tế TP. Hồ Chí Minh (UEH) - Cơ sở B là một trong những cơ sở đào tạo lớn và hiện đại nhất của nhà trường.", tooltip="Đại học Kinh tế HCM", icon=folium.Icon(icon="book")).add_to(m)

folium.Marker([10.754984, 106.670534], popup="""Bệnh viện Nguyễn Tri Phương là bệnh viện đa khoa hạng I trực thuộc Sở Y tế TP.HCM, cung cấp dịch vụ khám chữa bệnh với nhiều chuyên khoa như nội, ngoại, sản và cấp cứu.""", tooltip="Bệnh viện Nguyễn Tri Phương", icon=folium.Icon(icon="plus")).add_to(m)
folium.Marker([10.760872, 106.663252], popup="""Sân vận động Thống Nhất là một trong những sân vận động lâu đời tại TP.HCM, thường tổ chức các trận bóng đá, sự kiện thể thao và hoạt động văn hóa lớn.""", tooltip="Sân vận động Thống Nhất", icon=folium.Icon(icon="leaf")).add_to(m)
folium.Marker([10.758213, 106.672285], popup="""Khu chợ trong nhà với các mặt hàng đa dạng như vải vóc, quần áo, thực phẩm khô và đồ thủ công.""", tooltip="Chợ An Đông", icon=folium.Icon(icon="shopping-cart")).add_to(m)
folium.Marker([10.767971, 106.666631], popup="""UBND Phường Diên Hồng là cơ quan hành chính địa phương thực hiện quản lý nhà nước và giải quyết thủ tục hành chính cho người dân trên địa bàn phường.""", tooltip="UBND Phường Diên Hồng", icon=folium.Icon(icon="briefcase")).add_to(m)
folium.Marker([10.759996, 106.677605], popup="""Bến xe Phương Trang là điểm đón trả khách liên tỉnh của nhà xe Phương Trang tại TP.HCM, phục vụ nhiều tuyến đi miền Tây, miền Trung và Tây Nguyên.""", tooltip="Bến xe Phương Trang", icon=folium.Icon(icon="road")).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
